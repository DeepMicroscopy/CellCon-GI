# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader, WeightedRandomSampler, Dataset
from sklearn.model_selection import KFold
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
from tqdm import tqdm
import os
from PIL import Image
import logging
from datetime import datetime

# Setup logging
log_file = f"Ami-br_efficientnet_master_baseline.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # EfficientNet default size
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load data from folders
def load_data_from_folder(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Specify the classes
classes = ['Atypical', 'Normal']

# Load dataset
images, labels = load_data_from_folder(
    '/data/Mitosis_Detection/MICCAI25/AMI-Br_dataset/Train/Images', 
    classes
)

# Define the EfficientNet model for binary classification
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Training configuration
num_epochs = 100
batch_size = 128
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.BCELoss()
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Perform K-Fold Cross Validation
fold_accuracies = []

for fold, (train_idx, val_idx) in enumerate(kf.split(images, labels)):
    logger.info(f"Starting Fold {fold + 1}")

    # Split the raw lists into training and validation parts
    train_images = [images[i] for i in train_idx]
    train_labels = [labels[i] for i in train_idx]
    val_images = [images[i] for i in val_idx]
    val_labels = [labels[i] for i in val_idx]

    # Create separate Datasets with different transforms
    train_dataset = CustomDataset(train_images, train_labels, transform=train_transform)
    val_dataset = CustomDataset(val_images, val_labels, transform=val_transform)

    # Calculate class weights for WeightedRandomSampler
    class_counts = [0] * len(classes)
    for lbl in train_labels:
        class_counts[lbl] += 1
    class_weights = [1.0 / count for count in class_counts]

    sample_weights = [class_weights[lbl] for lbl in train_labels]
    sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)

    # Data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=sampler, num_workers=8, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=8, pin_memory=True)

    # Initialize model, optimizer, and scheduler
    model = BinaryEfficientNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

    best_val_balanced_accuracy = 0.0
    best_model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_preds = []
        train_targets = []

        # Training loop
        for images_batch, labels_batch in tqdm(train_loader, 
                                               desc=f"Fold {fold + 1} - Epoch {epoch + 1}/{num_epochs} - Training"):
            images_batch, labels_batch = images_batch.to(device), labels_batch.to(device)
            labels_batch = labels_batch.float().unsqueeze(1)

            optimizer.zero_grad()
            outputs = model(images_batch)
            loss = criterion(outputs, labels_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_preds.extend((outputs > 0.5).cpu().numpy())
            train_targets.extend(labels_batch.cpu().numpy())

        train_balanced_accuracy = balanced_accuracy_score(train_targets, train_preds)

        model.eval()
        val_loss = 0.0
        val_preds = []
        val_targets = []

        # Validation loop
        with torch.no_grad():
            for images_batch, labels_batch in tqdm(val_loader, 
                                                   desc=f"Fold {fold + 1} - Epoch {epoch + 1}/{num_epochs} - Validation"):
                images_batch, labels_batch = images_batch.to(device), labels_batch.to(device)
                labels_batch = labels_batch.float().unsqueeze(1)

                outputs = model(images_batch)
                loss = criterion(outputs, labels_batch)

                val_loss += loss.item()
                val_preds.extend((outputs > 0.5).cpu().numpy())
                val_targets.extend(labels_batch.cpu().numpy())

        val_balanced_accuracy = balanced_accuracy_score(val_targets, val_preds)

        if val_balanced_accuracy > best_val_balanced_accuracy:
            best_val_balanced_accuracy = val_balanced_accuracy
            torch.save(model.state_dict(), best_model_path)

        scheduler.step()

        # Logging metrics
        log_entry = (
            f"Fold {fold + 1}, Epoch {epoch + 1}/{num_epochs} | "
            f"Train Loss: {train_loss / len(train_loader):.4f}, "
            f"Train Balanced Accuracy: {train_balanced_accuracy:.4f} | "
            f"Val Loss: {val_loss / len(val_loader):.4f}, "
            f"Val Balanced Accuracy: {val_balanced_accuracy:.4f}"
        )
        logger.info(log_entry)

    logger.info(f"Fold {fold + 1} - Best Validation Balanced Accuracy: {best_val_balanced_accuracy:.4f}")
    fold_accuracies.append(best_val_balanced_accuracy)

# Calculate and log overall performance
average_accuracy = sum(fold_accuracies) / len(fold_accuracies)
logger.info(f"Average Validation Balanced Accuracy across all folds: {average_accuracy:.4f}")
# Out:
# 2025-02-15 19:09:52,976 - INFO - Starting Fold 1
# Loaded pretrained weights for efficientnet-b0
# Fold 1 - Epoch 1/100 - Training: 100%|██████████| 17/17 [00:04<00:00,  3.73it/s]
# Fold 1 - Epoch 1/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.30it/s]
# 2025-02-15 19:09:58,375 - INFO - Fold 1, Epoch 1/100 | Train Loss: 0.6516, Train Balanced Accuracy: 0.6128 | Val Loss: 0.8555, Val Balanced Accuracy: 0.6284
# Fold 1 - Epoch 2/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.92it/s]
# Fold 1 - Epoch 2/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.24it/s]
# 2025-02-15 19:10:02,481 - INFO - Fold 1, Epoch 2/100 | Train Loss: 0.4851, Train Balanced Accuracy: 0.7696 | Val Loss: 1.6584, Val Balanced Accuracy: 0.6970
# Fold 1 - Epoch 3/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.97it/s]
# Fold 1 - Epoch 3/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  9.08it/s]
# 2025-02-15 19:10:06,498 - INFO - Fold 1, Epoch 3/100 | Train Loss: 0.3747, Train Balanced Accuracy: 0.8398 | Val Loss: 1.3641, Val Balanced Accuracy: 0.7573
# Fold 1 - Epoch 4/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.95it/s]
# Fold 1 - Epoch 4/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.90it/s]
# 2025-02-15 19:10:10,502 - INFO - Fold 1, Epoch 4/100 | Train Loss: 0.3205, Train Balanced Accuracy: 0.8693 | Val Loss: 0.9380, Val Balanced Accuracy: 0.7226
# Fold 1 - Epoch 5/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.93it/s]
# Fold 1 - Epoch 5/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.42it/s]
# 2025-02-15 19:10:14,556 - INFO - Fold 1, Epoch 5/100 | Train Loss: 0.2512, Train Balanced Accuracy: 0.8990 | Val Loss: 0.7105, Val Balanced Accuracy: 0.7404
# Fold 1 - Epoch 6/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 1 - Epoch 6/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.87it/s]
# 2025-02-15 19:10:18,630 - INFO - Fold 1, Epoch 6/100 | Train Loss: 0.1830, Train Balanced Accuracy: 0.9303 | Val Loss: 0.6016, Val Balanced Accuracy: 0.7231
# Fold 1 - Epoch 7/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 7/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.83it/s]
# 2025-02-15 19:10:22,827 - INFO - Fold 1, Epoch 7/100 | Train Loss: 0.1754, Train Balanced Accuracy: 0.9319 | Val Loss: 0.5972, Val Balanced Accuracy: 0.6836
# Fold 1 - Epoch 8/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.83it/s]
# Fold 1 - Epoch 8/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.47it/s]
# 2025-02-15 19:10:26,948 - INFO - Fold 1, Epoch 8/100 | Train Loss: 0.1535, Train Balanced Accuracy: 0.9390 | Val Loss: 0.6746, Val Balanced Accuracy: 0.6688
# Fold 1 - Epoch 9/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 1 - Epoch 9/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.45it/s]
# 2025-02-15 19:10:31,059 - INFO - Fold 1, Epoch 9/100 | Train Loss: 0.1348, Train Balanced Accuracy: 0.9488 | Val Loss: 0.6573, Val Balanced Accuracy: 0.6902
# Fold 1 - Epoch 10/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.78it/s]
# Fold 1 - Epoch 10/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.87it/s]
# 2025-02-15 19:10:35,260 - INFO - Fold 1, Epoch 10/100 | Train Loss: 0.1035, Train Balanced Accuracy: 0.9660 | Val Loss: 0.6766, Val Balanced Accuracy: 0.7492
# Fold 1 - Epoch 11/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 1 - Epoch 11/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.07it/s]
# 2025-02-15 19:10:39,400 - INFO - Fold 1, Epoch 11/100 | Train Loss: 0.0906, Train Balanced Accuracy: 0.9698 | Val Loss: 0.5695, Val Balanced Accuracy: 0.7395
# Fold 1 - Epoch 12/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.82it/s]
# Fold 1 - Epoch 12/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.36it/s]
# 2025-02-15 19:10:43,529 - INFO - Fold 1, Epoch 12/100 | Train Loss: 0.0649, Train Balanced Accuracy: 0.9769 | Val Loss: 0.5597, Val Balanced Accuracy: 0.7429
# Fold 1 - Epoch 13/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.83it/s]
# Fold 1 - Epoch 13/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.86it/s]
# 2025-02-15 19:10:47,692 - INFO - Fold 1, Epoch 13/100 | Train Loss: 0.0500, Train Balanced Accuracy: 0.9826 | Val Loss: 0.5716, Val Balanced Accuracy: 0.7482
# Fold 1 - Epoch 14/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.97it/s]
# Fold 1 - Epoch 14/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  9.00it/s]
# 2025-02-15 19:10:51,676 - INFO - Fold 1, Epoch 14/100 | Train Loss: 0.0525, Train Balanced Accuracy: 0.9844 | Val Loss: 0.5726, Val Balanced Accuracy: 0.7355
# Fold 1 - Epoch 15/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 1 - Epoch 15/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.08it/s]
# 2025-02-15 19:10:55,822 - INFO - Fold 1, Epoch 15/100 | Train Loss: 0.0414, Train Balanced Accuracy: 0.9858 | Val Loss: 0.5430, Val Balanced Accuracy: 0.7628
# Fold 1 - Epoch 16/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 1 - Epoch 16/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.13it/s]
# 2025-02-15 19:10:59,961 - INFO - Fold 1, Epoch 16/100 | Train Loss: 0.0365, Train Balanced Accuracy: 0.9861 | Val Loss: 0.5457, Val Balanced Accuracy: 0.7752
# Fold 1 - Epoch 17/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 1 - Epoch 17/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.95it/s]
# 2025-02-15 19:11:04,058 - INFO - Fold 1, Epoch 17/100 | Train Loss: 0.0398, Train Balanced Accuracy: 0.9849 | Val Loss: 0.5430, Val Balanced Accuracy: 0.7773
# Fold 1 - Epoch 18/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.92it/s]
# Fold 1 - Epoch 18/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.21it/s]
# 2025-02-15 19:11:08,164 - INFO - Fold 1, Epoch 18/100 | Train Loss: 0.0280, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5524, Val Balanced Accuracy: 0.7882
# Fold 1 - Epoch 19/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s]
# Fold 1 - Epoch 19/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.21it/s]
# 2025-02-15 19:11:12,352 - INFO - Fold 1, Epoch 19/100 | Train Loss: 0.0296, Train Balanced Accuracy: 0.9910 | Val Loss: 0.5614, Val Balanced Accuracy: 0.8009
# Fold 1 - Epoch 20/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 1 - Epoch 20/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.68it/s]
# 2025-02-15 19:11:16,467 - INFO - Fold 1, Epoch 20/100 | Train Loss: 0.0214, Train Balanced Accuracy: 0.9934 | Val Loss: 0.5710, Val Balanced Accuracy: 0.8087
# Fold 1 - Epoch 21/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.96it/s]
# Fold 1 - Epoch 21/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.93it/s]
# 2025-02-15 19:11:20,572 - INFO - Fold 1, Epoch 21/100 | Train Loss: 0.0289, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5684, Val Balanced Accuracy: 0.8128
# Fold 1 - Epoch 22/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.71it/s]
# Fold 1 - Epoch 22/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.06it/s]
# 2025-02-15 19:11:24,844 - INFO - Fold 1, Epoch 22/100 | Train Loss: 0.0261, Train Balanced Accuracy: 0.9910 | Val Loss: 0.5632, Val Balanced Accuracy: 0.8140
# Fold 1 - Epoch 23/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 23/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.30it/s]
# 2025-02-15 19:11:29,004 - INFO - Fold 1, Epoch 23/100 | Train Loss: 0.0212, Train Balanced Accuracy: 0.9938 | Val Loss: 0.5588, Val Balanced Accuracy: 0.8140
# Fold 1 - Epoch 24/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.89it/s]
# Fold 1 - Epoch 24/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.15it/s]
# 2025-02-15 19:11:33,100 - INFO - Fold 1, Epoch 24/100 | Train Loss: 0.0218, Train Balanced Accuracy: 0.9910 | Val Loss: 0.5562, Val Balanced Accuracy: 0.8100
# Fold 1 - Epoch 25/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.80it/s]
# Fold 1 - Epoch 25/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.11it/s]
# 2025-02-15 19:11:37,268 - INFO - Fold 1, Epoch 25/100 | Train Loss: 0.0262, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5567, Val Balanced Accuracy: 0.8059
# Fold 1 - Epoch 26/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 1 - Epoch 26/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.16it/s]
# 2025-02-15 19:11:41,373 - INFO - Fold 1, Epoch 26/100 | Train Loss: 0.0273, Train Balanced Accuracy: 0.9938 | Val Loss: 0.5540, Val Balanced Accuracy: 0.8019
# Fold 1 - Epoch 27/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.91it/s]
# Fold 1 - Epoch 27/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.21it/s]
# 2025-02-15 19:11:45,452 - INFO - Fold 1, Epoch 27/100 | Train Loss: 0.0254, Train Balanced Accuracy: 0.9914 | Val Loss: 0.5511, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 28/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 1 - Epoch 28/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.31it/s]
# 2025-02-15 19:11:49,576 - INFO - Fold 1, Epoch 28/100 | Train Loss: 0.0279, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5499, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 29/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.74it/s]
# Fold 1 - Epoch 29/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.14it/s]
# 2025-02-15 19:11:53,784 - INFO - Fold 1, Epoch 29/100 | Train Loss: 0.0232, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5504, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 30/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.80it/s]
# Fold 1 - Epoch 30/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.13it/s]
# 2025-02-15 19:11:57,946 - INFO - Fold 1, Epoch 30/100 | Train Loss: 0.0219, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5501, Val Balanced Accuracy: 0.8056
# Fold 1 - Epoch 31/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 1 - Epoch 31/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.68it/s]
# 2025-02-15 19:12:02,098 - INFO - Fold 1, Epoch 31/100 | Train Loss: 0.0278, Train Balanced Accuracy: 0.9926 | Val Loss: 0.5510, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 32/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.89it/s]
# Fold 1 - Epoch 32/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.67it/s]
# 2025-02-15 19:12:06,161 - INFO - Fold 1, Epoch 32/100 | Train Loss: 0.0242, Train Balanced Accuracy: 0.9910 | Val Loss: 0.5510, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 33/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.98it/s]
# Fold 1 - Epoch 33/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.54it/s]
# 2025-02-15 19:12:10,169 - INFO - Fold 1, Epoch 33/100 | Train Loss: 0.0157, Train Balanced Accuracy: 0.9953 | Val Loss: 0.5504, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 34/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 1 - Epoch 34/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.50it/s]
# 2025-02-15 19:12:14,413 - INFO - Fold 1, Epoch 34/100 | Train Loss: 0.0259, Train Balanced Accuracy: 0.9943 | Val Loss: 0.5505, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 35/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.77it/s]
# Fold 1 - Epoch 35/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.41it/s]
# 2025-02-15 19:12:18,578 - INFO - Fold 1, Epoch 35/100 | Train Loss: 0.0217, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5508, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 36/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 1 - Epoch 36/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.95it/s]
# 2025-02-15 19:12:22,641 - INFO - Fold 1, Epoch 36/100 | Train Loss: 0.0179, Train Balanced Accuracy: 0.9967 | Val Loss: 0.5499, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 37/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.90it/s]
# Fold 1 - Epoch 37/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.76it/s]
# 2025-02-15 19:12:26,767 - INFO - Fold 1, Epoch 37/100 | Train Loss: 0.0223, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5493, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 38/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 38/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.69it/s]
# 2025-02-15 19:12:30,904 - INFO - Fold 1, Epoch 38/100 | Train Loss: 0.0207, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5492, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 39/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 1 - Epoch 39/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.29it/s]
# 2025-02-15 19:12:35,002 - INFO - Fold 1, Epoch 39/100 | Train Loss: 0.0306, Train Balanced Accuracy: 0.9905 | Val Loss: 0.5485, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 40/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.83it/s]
# Fold 1 - Epoch 40/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.50it/s]
# 2025-02-15 19:12:39,121 - INFO - Fold 1, Epoch 40/100 | Train Loss: 0.0229, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5478, Val Balanced Accuracy: 0.8096
# Fold 1 - Epoch 41/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 1 - Epoch 41/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.22it/s]
# 2025-02-15 19:12:43,317 - INFO - Fold 1, Epoch 41/100 | Train Loss: 0.0168, Train Balanced Accuracy: 0.9976 | Val Loss: 0.5487, Val Balanced Accuracy: 0.8096
# Fold 1 - Epoch 42/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.94it/s]
# Fold 1 - Epoch 42/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.72it/s]
# 2025-02-15 19:12:47,414 - INFO - Fold 1, Epoch 42/100 | Train Loss: 0.0252, Train Balanced Accuracy: 0.9930 | Val Loss: 0.5482, Val Balanced Accuracy: 0.8096
# Fold 1 - Epoch 43/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.71it/s]
# Fold 1 - Epoch 43/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.77it/s]
# 2025-02-15 19:12:51,680 - INFO - Fold 1, Epoch 43/100 | Train Loss: 0.0244, Train Balanced Accuracy: 0.9919 | Val Loss: 0.5488, Val Balanced Accuracy: 0.8096
# Fold 1 - Epoch 44/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 1 - Epoch 44/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.49it/s]
# 2025-02-15 19:12:55,760 - INFO - Fold 1, Epoch 44/100 | Train Loss: 0.0197, Train Balanced Accuracy: 0.9948 | Val Loss: 0.5477, Val Balanced Accuracy: 0.8096
# Fold 1 - Epoch 45/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.78it/s]
# Fold 1 - Epoch 45/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.37it/s]
# 2025-02-15 19:12:59,925 - INFO - Fold 1, Epoch 45/100 | Train Loss: 0.0240, Train Balanced Accuracy: 0.9934 | Val Loss: 0.5482, Val Balanced Accuracy: 0.8096
# Fold 1 - Epoch 46/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.96it/s]
# Fold 1 - Epoch 46/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.72it/s]
# 2025-02-15 19:13:03,933 - INFO - Fold 1, Epoch 46/100 | Train Loss: 0.0224, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5474, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 47/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.97it/s]
# Fold 1 - Epoch 47/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.04it/s]
# 2025-02-15 19:13:07,984 - INFO - Fold 1, Epoch 47/100 | Train Loss: 0.0239, Train Balanced Accuracy: 0.9920 | Val Loss: 0.5469, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 48/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 1 - Epoch 48/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.25it/s]
# 2025-02-15 19:13:12,179 - INFO - Fold 1, Epoch 48/100 | Train Loss: 0.0248, Train Balanced Accuracy: 0.9934 | Val Loss: 0.5473, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 49/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 1 - Epoch 49/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.68it/s]
# 2025-02-15 19:13:16,332 - INFO - Fold 1, Epoch 49/100 | Train Loss: 0.0232, Train Balanced Accuracy: 0.9919 | Val Loss: 0.5485, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 50/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 1 - Epoch 50/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.62it/s]
# 2025-02-15 19:13:20,503 - INFO - Fold 1, Epoch 50/100 | Train Loss: 0.0240, Train Balanced Accuracy: 0.9928 | Val Loss: 0.5477, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 51/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 1 - Epoch 51/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.48it/s]
# 2025-02-15 19:13:24,761 - INFO - Fold 1, Epoch 51/100 | Train Loss: 0.0218, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5485, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 52/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.90it/s]
# Fold 1 - Epoch 52/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.36it/s]
# 2025-02-15 19:13:28,834 - INFO - Fold 1, Epoch 52/100 | Train Loss: 0.0177, Train Balanced Accuracy: 0.9962 | Val Loss: 0.5481, Val Balanced Accuracy: 0.8041
# Fold 1 - Epoch 53/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.83it/s]
# Fold 1 - Epoch 53/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.77it/s]
# 2025-02-15 19:13:33,007 - INFO - Fold 1, Epoch 53/100 | Train Loss: 0.0212, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5482, Val Balanced Accuracy: 0.8041
# Fold 1 - Epoch 54/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.94it/s]
# Fold 1 - Epoch 54/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.29it/s]
# 2025-02-15 19:13:37,059 - INFO - Fold 1, Epoch 54/100 | Train Loss: 0.0257, Train Balanced Accuracy: 0.9944 | Val Loss: 0.5485, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 55/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.67it/s]
# Fold 1 - Epoch 55/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.56it/s]
# 2025-02-15 19:13:41,297 - INFO - Fold 1, Epoch 55/100 | Train Loss: 0.0266, Train Balanced Accuracy: 0.9916 | Val Loss: 0.5477, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 56/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.92it/s]
# Fold 1 - Epoch 56/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.24it/s]
# 2025-02-15 19:13:45,370 - INFO - Fold 1, Epoch 56/100 | Train Loss: 0.0288, Train Balanced Accuracy: 0.9914 | Val Loss: 0.5468, Val Balanced Accuracy: 0.8081
# Fold 1 - Epoch 57/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 1 - Epoch 57/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.74it/s]
# 2025-02-15 19:13:49,452 - INFO - Fold 1, Epoch 57/100 | Train Loss: 0.0249, Train Balanced Accuracy: 0.9943 | Val Loss: 0.5470, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 58/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.91it/s]
# Fold 1 - Epoch 58/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.92it/s]
# 2025-02-15 19:13:53,484 - INFO - Fold 1, Epoch 58/100 | Train Loss: 0.0241, Train Balanced Accuracy: 0.9934 | Val Loss: 0.5479, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 59/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.97it/s]
# Fold 1 - Epoch 59/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.88it/s]
# 2025-02-15 19:13:57,551 - INFO - Fold 1, Epoch 59/100 | Train Loss: 0.0219, Train Balanced Accuracy: 0.9939 | Val Loss: 0.5487, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 60/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 1 - Epoch 60/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.74it/s]
# 2025-02-15 19:14:01,702 - INFO - Fold 1, Epoch 60/100 | Train Loss: 0.0218, Train Balanced Accuracy: 0.9934 | Val Loss: 0.5484, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 61/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.66it/s]
# Fold 1 - Epoch 61/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.06it/s]
# 2025-02-15 19:14:05,978 - INFO - Fold 1, Epoch 61/100 | Train Loss: 0.0229, Train Balanced Accuracy: 0.9942 | Val Loss: 0.5488, Val Balanced Accuracy: 0.8081
# Fold 1 - Epoch 62/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s]
# Fold 1 - Epoch 62/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.30it/s]
# 2025-02-15 19:14:10,124 - INFO - Fold 1, Epoch 62/100 | Train Loss: 0.0251, Train Balanced Accuracy: 0.9930 | Val Loss: 0.5494, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 63/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 63/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.45it/s]
# 2025-02-15 19:14:14,278 - INFO - Fold 1, Epoch 63/100 | Train Loss: 0.0308, Train Balanced Accuracy: 0.9919 | Val Loss: 0.5491, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 64/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.72it/s]
# Fold 1 - Epoch 64/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.99it/s]
# 2025-02-15 19:14:18,517 - INFO - Fold 1, Epoch 64/100 | Train Loss: 0.0302, Train Balanced Accuracy: 0.9900 | Val Loss: 0.5487, Val Balanced Accuracy: 0.8041
# Fold 1 - Epoch 65/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.73it/s]
# Fold 1 - Epoch 65/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.82it/s]
# 2025-02-15 19:14:22,758 - INFO - Fold 1, Epoch 65/100 | Train Loss: 0.0211, Train Balanced Accuracy: 0.9943 | Val Loss: 0.5493, Val Balanced Accuracy: 0.8081
# Fold 1 - Epoch 66/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 1 - Epoch 66/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.37it/s]
# 2025-02-15 19:14:26,875 - INFO - Fold 1, Epoch 66/100 | Train Loss: 0.0226, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5489, Val Balanced Accuracy: 0.8121
# Fold 1 - Epoch 67/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.73it/s]
# Fold 1 - Epoch 67/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.04it/s]
# 2025-02-15 19:14:31,097 - INFO - Fold 1, Epoch 67/100 | Train Loss: 0.0260, Train Balanced Accuracy: 0.9939 | Val Loss: 0.5488, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 68/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 1 - Epoch 68/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.45it/s]
# 2025-02-15 19:14:35,198 - INFO - Fold 1, Epoch 68/100 | Train Loss: 0.0371, Train Balanced Accuracy: 0.9899 | Val Loss: 0.5490, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 69/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.98it/s]
# Fold 1 - Epoch 69/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.52it/s]
# 2025-02-15 19:14:39,207 - INFO - Fold 1, Epoch 69/100 | Train Loss: 0.0208, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5489, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 70/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.91it/s]
# Fold 1 - Epoch 70/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.63it/s]
# 2025-02-15 19:14:43,256 - INFO - Fold 1, Epoch 70/100 | Train Loss: 0.0246, Train Balanced Accuracy: 0.9931 | Val Loss: 0.5490, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 71/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.94it/s]
# Fold 1 - Epoch 71/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  9.00it/s]
# 2025-02-15 19:14:47,260 - INFO - Fold 1, Epoch 71/100 | Train Loss: 0.0270, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5489, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 72/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 72/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.23it/s]
# 2025-02-15 19:14:51,424 - INFO - Fold 1, Epoch 72/100 | Train Loss: 0.0216, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5493, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 73/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.90it/s]
# Fold 1 - Epoch 73/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.87it/s]
# 2025-02-15 19:14:55,537 - INFO - Fold 1, Epoch 73/100 | Train Loss: 0.0250, Train Balanced Accuracy: 0.9930 | Val Loss: 0.5498, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 74/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 74/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.21it/s]
# 2025-02-15 19:14:59,704 - INFO - Fold 1, Epoch 74/100 | Train Loss: 0.0285, Train Balanced Accuracy: 0.9886 | Val Loss: 0.5501, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 75/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.87it/s]
# Fold 1 - Epoch 75/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.66it/s]
# 2025-02-15 19:15:03,858 - INFO - Fold 1, Epoch 75/100 | Train Loss: 0.0207, Train Balanced Accuracy: 0.9943 | Val Loss: 0.5494, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 76/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.78it/s]
# Fold 1 - Epoch 76/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.79it/s]
# 2025-02-15 19:15:08,068 - INFO - Fold 1, Epoch 76/100 | Train Loss: 0.0286, Train Balanced Accuracy: 0.9925 | Val Loss: 0.5500, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 77/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.82it/s]
# Fold 1 - Epoch 77/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.97it/s]
# 2025-02-15 19:15:12,229 - INFO - Fold 1, Epoch 77/100 | Train Loss: 0.0186, Train Balanced Accuracy: 0.9967 | Val Loss: 0.5494, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 78/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.71it/s]
# Fold 1 - Epoch 78/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.75it/s]
# 2025-02-15 19:15:16,493 - INFO - Fold 1, Epoch 78/100 | Train Loss: 0.0253, Train Balanced Accuracy: 0.9925 | Val Loss: 0.5499, Val Balanced Accuracy: 0.8124
# Fold 1 - Epoch 79/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 1 - Epoch 79/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.91it/s]
# 2025-02-15 19:15:20,621 - INFO - Fold 1, Epoch 79/100 | Train Loss: 0.0215, Train Balanced Accuracy: 0.9944 | Val Loss: 0.5504, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 80/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 1 - Epoch 80/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.55it/s]
# 2025-02-15 19:15:24,869 - INFO - Fold 1, Epoch 80/100 | Train Loss: 0.0271, Train Balanced Accuracy: 0.9920 | Val Loss: 0.5504, Val Balanced Accuracy: 0.8084
# Fold 1 - Epoch 81/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 81/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.76it/s]
# 2025-02-15 19:15:29,075 - INFO - Fold 1, Epoch 81/100 | Train Loss: 0.0178, Train Balanced Accuracy: 0.9971 | Val Loss: 0.5498, Val Balanced Accuracy: 0.8072
# Fold 1 - Epoch 82/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 1 - Epoch 82/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.22it/s]
# 2025-02-15 19:15:33,201 - INFO - Fold 1, Epoch 82/100 | Train Loss: 0.0181, Train Balanced Accuracy: 0.9958 | Val Loss: 0.5503, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 83/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.77it/s]
# Fold 1 - Epoch 83/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.95it/s]
# 2025-02-15 19:15:37,403 - INFO - Fold 1, Epoch 83/100 | Train Loss: 0.0230, Train Balanced Accuracy: 0.9938 | Val Loss: 0.5486, Val Balanced Accuracy: 0.8096
# Fold 1 - Epoch 84/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 1 - Epoch 84/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.17it/s]
# 2025-02-15 19:15:41,596 - INFO - Fold 1, Epoch 84/100 | Train Loss: 0.0183, Train Balanced Accuracy: 0.9962 | Val Loss: 0.5488, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 85/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 1 - Epoch 85/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.13it/s]
# 2025-02-15 19:15:45,735 - INFO - Fold 1, Epoch 85/100 | Train Loss: 0.0286, Train Balanced Accuracy: 0.9916 | Val Loss: 0.5485, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 86/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.82it/s]
# Fold 1 - Epoch 86/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.88it/s]
# 2025-02-15 19:15:49,905 - INFO - Fold 1, Epoch 86/100 | Train Loss: 0.0259, Train Balanced Accuracy: 0.9929 | Val Loss: 0.5476, Val Balanced Accuracy: 0.8069
# Fold 1 - Epoch 87/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.80it/s]
# Fold 1 - Epoch 87/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.83it/s]
# 2025-02-15 19:15:54,023 - INFO - Fold 1, Epoch 87/100 | Train Loss: 0.0262, Train Balanced Accuracy: 0.9915 | Val Loss: 0.5489, Val Balanced Accuracy: 0.8069
# Fold 1 - Epoch 88/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.93it/s]
# Fold 1 - Epoch 88/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.91it/s]
# 2025-02-15 19:15:58,044 - INFO - Fold 1, Epoch 88/100 | Train Loss: 0.0243, Train Balanced Accuracy: 0.9943 | Val Loss: 0.5487, Val Balanced Accuracy: 0.8109
# Fold 1 - Epoch 89/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.74it/s]
# Fold 1 - Epoch 89/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.43it/s]
# 2025-02-15 19:16:02,310 - INFO - Fold 1, Epoch 89/100 | Train Loss: 0.0219, Train Balanced Accuracy: 0.9925 | Val Loss: 0.5489, Val Balanced Accuracy: 0.8137
# Fold 1 - Epoch 90/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.71it/s]
# Fold 1 - Epoch 90/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.45it/s]
# 2025-02-15 19:16:06,602 - INFO - Fold 1, Epoch 90/100 | Train Loss: 0.0231, Train Balanced Accuracy: 0.9948 | Val Loss: 0.5488, Val Balanced Accuracy: 0.8124
# Fold 1 - Epoch 91/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.71it/s]
# Fold 1 - Epoch 91/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.48it/s]
# 2025-02-15 19:16:10,891 - INFO - Fold 1, Epoch 91/100 | Train Loss: 0.0242, Train Balanced Accuracy: 0.9915 | Val Loss: 0.5499, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 92/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.70it/s]
# Fold 1 - Epoch 92/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.84it/s]
# 2025-02-15 19:16:15,158 - INFO - Fold 1, Epoch 92/100 | Train Loss: 0.0296, Train Balanced Accuracy: 0.9911 | Val Loss: 0.5506, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 93/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.80it/s]
# Fold 1 - Epoch 93/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.82it/s]
# 2025-02-15 19:16:19,345 - INFO - Fold 1, Epoch 93/100 | Train Loss: 0.0241, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5502, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 94/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 1 - Epoch 94/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.86it/s]
# 2025-02-15 19:16:23,497 - INFO - Fold 1, Epoch 94/100 | Train Loss: 0.0224, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5492, Val Balanced Accuracy: 0.8124
# Fold 1 - Epoch 95/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 1 - Epoch 95/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.93it/s]
# 2025-02-15 19:16:27,616 - INFO - Fold 1, Epoch 95/100 | Train Loss: 0.0202, Train Balanced Accuracy: 0.9943 | Val Loss: 0.5498, Val Balanced Accuracy: 0.8124
# Fold 1 - Epoch 96/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s]
# Fold 1 - Epoch 96/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.98it/s]
# 2025-02-15 19:16:31,718 - INFO - Fold 1, Epoch 96/100 | Train Loss: 0.0193, Train Balanced Accuracy: 0.9957 | Val Loss: 0.5499, Val Balanced Accuracy: 0.8124
# Fold 1 - Epoch 97/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.82it/s]
# Fold 1 - Epoch 97/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.75it/s]
# 2025-02-15 19:16:35,822 - INFO - Fold 1, Epoch 97/100 | Train Loss: 0.0232, Train Balanced Accuracy: 0.9933 | Val Loss: 0.5504, Val Balanced Accuracy: 0.8124
# Fold 1 - Epoch 98/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.90it/s]
# Fold 1 - Epoch 98/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.87it/s]
# 2025-02-15 19:16:39,934 - INFO - Fold 1, Epoch 98/100 | Train Loss: 0.0289, Train Balanced Accuracy: 0.9924 | Val Loss: 0.5513, Val Balanced Accuracy: 0.8112
# Fold 1 - Epoch 99/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.80it/s]
# Fold 1 - Epoch 99/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.26it/s]
# 2025-02-15 19:16:44,088 - INFO - Fold 1, Epoch 99/100 | Train Loss: 0.0280, Train Balanced Accuracy: 0.9896 | Val Loss: 0.5515, Val Balanced Accuracy: 0.8124
# Fold 1 - Epoch 100/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.77it/s]
# Fold 1 - Epoch 100/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.96it/s]
# 2025-02-15 19:16:48,286 - INFO - Fold 1, Epoch 100/100 | Train Loss: 0.0225, Train Balanced Accuracy: 0.9943 | Val Loss: 0.5512, Val Balanced Accuracy: 0.8112
# 2025-02-15 19:16:48,286 - INFO - Fold 1 - Best Validation Balanced Accuracy: 0.8140
# 2025-02-15 19:16:48,286 - INFO - Starting Fold 2
# Loaded pretrained weights for efficientnet-b0
# Fold 2 - Epoch 1/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s]
# Fold 2 - Epoch 1/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.49it/s]
# 2025-02-15 19:16:52,595 - INFO - Fold 2, Epoch 1/100 | Train Loss: 0.6317, Train Balanced Accuracy: 0.6275 | Val Loss: 1.6802, Val Balanced Accuracy: 0.5224
# Fold 2 - Epoch 2/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.72it/s]
# Fold 2 - Epoch 2/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.09it/s]
# 2025-02-15 19:16:56,865 - INFO - Fold 2, Epoch 2/100 | Train Loss: 0.4899, Train Balanced Accuracy: 0.7663 | Val Loss: 0.9730, Val Balanced Accuracy: 0.7208
# Fold 2 - Epoch 3/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.73it/s]
# Fold 2 - Epoch 3/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.60it/s]
# 2025-02-15 19:17:01,169 - INFO - Fold 2, Epoch 3/100 | Train Loss: 0.3909, Train Balanced Accuracy: 0.8284 | Val Loss: 0.7073, Val Balanced Accuracy: 0.7472
# Fold 2 - Epoch 4/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.72it/s]
# Fold 2 - Epoch 4/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.10it/s]
# 2025-02-15 19:17:05,400 - INFO - Fold 2, Epoch 4/100 | Train Loss: 0.3131, Train Balanced Accuracy: 0.8739 | Val Loss: 0.5843, Val Balanced Accuracy: 0.7437
# Fold 2 - Epoch 5/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 2 - Epoch 5/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.48it/s]
# 2025-02-15 19:17:09,662 - INFO - Fold 2, Epoch 5/100 | Train Loss: 0.2554, Train Balanced Accuracy: 0.8882 | Val Loss: 1.2053, Val Balanced Accuracy: 0.7405
# Fold 2 - Epoch 6/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.78it/s]
# Fold 2 - Epoch 6/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.90it/s]
# 2025-02-15 19:17:13,860 - INFO - Fold 2, Epoch 6/100 | Train Loss: 0.1822, Train Balanced Accuracy: 0.9260 | Val Loss: 0.9690, Val Balanced Accuracy: 0.7233
# Fold 2 - Epoch 7/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 2 - Epoch 7/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.29it/s]
# 2025-02-15 19:17:18,075 - INFO - Fold 2, Epoch 7/100 | Train Loss: 0.1584, Train Balanced Accuracy: 0.9384 | Val Loss: 0.7377, Val Balanced Accuracy: 0.7552
# Fold 2 - Epoch 8/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.74it/s]
# Fold 2 - Epoch 8/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.35it/s]
# 2025-02-15 19:17:22,272 - INFO - Fold 2, Epoch 8/100 | Train Loss: 0.1486, Train Balanced Accuracy: 0.9455 | Val Loss: 0.7153, Val Balanced Accuracy: 0.7184
# Fold 2 - Epoch 9/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 2 - Epoch 9/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.66it/s]
# 2025-02-15 19:17:26,516 - INFO - Fold 2, Epoch 9/100 | Train Loss: 0.1204, Train Balanced Accuracy: 0.9536 | Val Loss: 0.8713, Val Balanced Accuracy: 0.6391
# Fold 2 - Epoch 10/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s]
# Fold 2 - Epoch 10/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.23it/s]
# 2025-02-15 19:17:30,664 - INFO - Fold 2, Epoch 10/100 | Train Loss: 0.1017, Train Balanced Accuracy: 0.9649 | Val Loss: 0.7400, Val Balanced Accuracy: 0.7394
# Fold 2 - Epoch 11/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 2 - Epoch 11/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.68it/s]
# 2025-02-15 19:17:34,840 - INFO - Fold 2, Epoch 11/100 | Train Loss: 0.0797, Train Balanced Accuracy: 0.9729 | Val Loss: 0.7294, Val Balanced Accuracy: 0.7378
# Fold 2 - Epoch 12/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.65it/s]
# Fold 2 - Epoch 12/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.45it/s]
# 2025-02-15 19:17:39,180 - INFO - Fold 2, Epoch 12/100 | Train Loss: 0.0605, Train Balanced Accuracy: 0.9783 | Val Loss: 0.7620, Val Balanced Accuracy: 0.7513
# Fold 2 - Epoch 13/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.78it/s]
# Fold 2 - Epoch 13/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.01it/s]
# 2025-02-15 19:17:43,372 - INFO - Fold 2, Epoch 13/100 | Train Loss: 0.0437, Train Balanced Accuracy: 0.9867 | Val Loss: 0.7620, Val Balanced Accuracy: 0.7463
# Fold 2 - Epoch 14/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.68it/s]
# Fold 2 - Epoch 14/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.43it/s]
# 2025-02-15 19:17:47,610 - INFO - Fold 2, Epoch 14/100 | Train Loss: 0.0439, Train Balanced Accuracy: 0.9869 | Val Loss: 0.7521, Val Balanced Accuracy: 0.7525
# Fold 2 - Epoch 15/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 2 - Epoch 15/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.21it/s]
# 2025-02-15 19:17:51,781 - INFO - Fold 2, Epoch 15/100 | Train Loss: 0.0448, Train Balanced Accuracy: 0.9858 | Val Loss: 0.6952, Val Balanced Accuracy: 0.7441
# Fold 2 - Epoch 16/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.74it/s]
# Fold 2 - Epoch 16/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.78it/s]
# 2025-02-15 19:17:56,019 - INFO - Fold 2, Epoch 16/100 | Train Loss: 0.0395, Train Balanced Accuracy: 0.9867 | Val Loss: 0.6983, Val Balanced Accuracy: 0.7390
# Fold 2 - Epoch 17/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.72it/s]
# Fold 2 - Epoch 17/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.73it/s]
# 2025-02-15 19:18:00,276 - INFO - Fold 2, Epoch 17/100 | Train Loss: 0.0414, Train Balanced Accuracy: 0.9848 | Val Loss: 0.6569, Val Balanced Accuracy: 0.7393
# Fold 2 - Epoch 18/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.70it/s]
# Fold 2 - Epoch 18/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.05it/s]
# 2025-02-15 19:18:04,524 - INFO - Fold 2, Epoch 18/100 | Train Loss: 0.0306, Train Balanced Accuracy: 0.9899 | Val Loss: 0.6541, Val Balanced Accuracy: 0.7356
# Fold 2 - Epoch 19/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 2 - Epoch 19/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.86it/s]
# 2025-02-15 19:18:08,746 - INFO - Fold 2, Epoch 19/100 | Train Loss: 0.0271, Train Balanced Accuracy: 0.9910 | Val Loss: 0.6283, Val Balanced Accuracy: 0.7332
# Fold 2 - Epoch 20/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 2 - Epoch 20/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.26it/s]
# 2025-02-15 19:18:12,870 - INFO - Fold 2, Epoch 20/100 | Train Loss: 0.0279, Train Balanced Accuracy: 0.9915 | Val Loss: 0.6164, Val Balanced Accuracy: 0.7321
# Fold 2 - Epoch 21/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 2 - Epoch 21/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.55it/s]
# 2025-02-15 19:18:16,950 - INFO - Fold 2, Epoch 21/100 | Train Loss: 0.0292, Train Balanced Accuracy: 0.9910 | Val Loss: 0.6188, Val Balanced Accuracy: 0.7211
# Fold 2 - Epoch 22/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.77it/s]
# Fold 2 - Epoch 22/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.76it/s]
# 2025-02-15 19:18:21,171 - INFO - Fold 2, Epoch 22/100 | Train Loss: 0.0291, Train Balanced Accuracy: 0.9910 | Val Loss: 0.6235, Val Balanced Accuracy: 0.7248
# Fold 2 - Epoch 23/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.83it/s]
# Fold 2 - Epoch 23/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.54it/s]
# 2025-02-15 19:18:25,285 - INFO - Fold 2, Epoch 23/100 | Train Loss: 0.0219, Train Balanced Accuracy: 0.9943 | Val Loss: 0.6271, Val Balanced Accuracy: 0.7272
# Fold 2 - Epoch 24/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.96it/s]
# Fold 2 - Epoch 24/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.61it/s]
# 2025-02-15 19:18:29,305 - INFO - Fold 2, Epoch 24/100 | Train Loss: 0.0214, Train Balanced Accuracy: 0.9948 | Val Loss: 0.6292, Val Balanced Accuracy: 0.7335
# Fold 2 - Epoch 25/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 2 - Epoch 25/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.17it/s]
# 2025-02-15 19:18:33,477 - INFO - Fold 2, Epoch 25/100 | Train Loss: 0.0215, Train Balanced Accuracy: 0.9919 | Val Loss: 0.6334, Val Balanced Accuracy: 0.7347
# Fold 2 - Epoch 26/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 2 - Epoch 26/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.64it/s]
# 2025-02-15 19:18:37,651 - INFO - Fold 2, Epoch 26/100 | Train Loss: 0.0228, Train Balanced Accuracy: 0.9943 | Val Loss: 0.6365, Val Balanced Accuracy: 0.7347
# Fold 2 - Epoch 27/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.95it/s]
# Fold 2 - Epoch 27/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.66it/s]
# 2025-02-15 19:18:41,668 - INFO - Fold 2, Epoch 27/100 | Train Loss: 0.0268, Train Balanced Accuracy: 0.9934 | Val Loss: 0.6365, Val Balanced Accuracy: 0.7335
# Fold 2 - Epoch 28/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.90it/s]
# Fold 2 - Epoch 28/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.04it/s]
# 2025-02-15 19:18:45,767 - INFO - Fold 2, Epoch 28/100 | Train Loss: 0.0263, Train Balanced Accuracy: 0.9920 | Val Loss: 0.6396, Val Balanced Accuracy: 0.7273
# Fold 2 - Epoch 29/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.95it/s]
# Fold 2 - Epoch 29/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.57it/s]
# 2025-02-15 19:18:49,797 - INFO - Fold 2, Epoch 29/100 | Train Loss: 0.0255, Train Balanced Accuracy: 0.9924 | Val Loss: 0.6405, Val Balanced Accuracy: 0.7298
# Fold 2 - Epoch 30/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.90it/s]
# Fold 2 - Epoch 30/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.02it/s]
# 2025-02-15 19:18:53,902 - INFO - Fold 2, Epoch 30/100 | Train Loss: 0.0228, Train Balanced Accuracy: 0.9957 | Val Loss: 0.6411, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 31/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 2 - Epoch 31/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.85it/s]
# 2025-02-15 19:18:58,044 - INFO - Fold 2, Epoch 31/100 | Train Loss: 0.0195, Train Balanced Accuracy: 0.9952 | Val Loss: 0.6423, Val Balanced Accuracy: 0.7273
# Fold 2 - Epoch 32/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.65it/s]
# Fold 2 - Epoch 32/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.36it/s]
# 2025-02-15 19:19:02,304 - INFO - Fold 2, Epoch 32/100 | Train Loss: 0.0249, Train Balanced Accuracy: 0.9924 | Val Loss: 0.6442, Val Balanced Accuracy: 0.7273
# Fold 2 - Epoch 33/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.74it/s]
# Fold 2 - Epoch 33/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.24it/s]
# 2025-02-15 19:19:06,505 - INFO - Fold 2, Epoch 33/100 | Train Loss: 0.0197, Train Balanced Accuracy: 0.9939 | Val Loss: 0.6448, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 34/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.90it/s]
# Fold 2 - Epoch 34/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.82it/s]
# 2025-02-15 19:19:10,621 - INFO - Fold 2, Epoch 34/100 | Train Loss: 0.0188, Train Balanced Accuracy: 0.9943 | Val Loss: 0.6475, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 35/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.93it/s]
# Fold 2 - Epoch 35/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.74it/s]
# 2025-02-15 19:19:14,650 - INFO - Fold 2, Epoch 35/100 | Train Loss: 0.0179, Train Balanced Accuracy: 0.9962 | Val Loss: 0.6476, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 36/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 2 - Epoch 36/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.71it/s]
# 2025-02-15 19:19:18,731 - INFO - Fold 2, Epoch 36/100 | Train Loss: 0.0265, Train Balanced Accuracy: 0.9905 | Val Loss: 0.6465, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 37/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s]
# Fold 2 - Epoch 37/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.33it/s]
# 2025-02-15 19:19:22,876 - INFO - Fold 2, Epoch 37/100 | Train Loss: 0.0189, Train Balanced Accuracy: 0.9929 | Val Loss: 0.6471, Val Balanced Accuracy: 0.7323
# Fold 2 - Epoch 38/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.96it/s]
# Fold 2 - Epoch 38/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.55it/s]
# 2025-02-15 19:19:26,898 - INFO - Fold 2, Epoch 38/100 | Train Loss: 0.0161, Train Balanced Accuracy: 0.9968 | Val Loss: 0.6454, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 39/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 2 - Epoch 39/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.07it/s]
# 2025-02-15 19:19:31,022 - INFO - Fold 2, Epoch 39/100 | Train Loss: 0.0214, Train Balanced Accuracy: 0.9943 | Val Loss: 0.6452, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 40/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 2 - Epoch 40/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.05it/s]
# 2025-02-15 19:19:35,149 - INFO - Fold 2, Epoch 40/100 | Train Loss: 0.0210, Train Balanced Accuracy: 0.9934 | Val Loss: 0.6444, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 41/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 2 - Epoch 41/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.62it/s]
# 2025-02-15 19:19:39,287 - INFO - Fold 2, Epoch 41/100 | Train Loss: 0.0197, Train Balanced Accuracy: 0.9948 | Val Loss: 0.6440, Val Balanced Accuracy: 0.7323
# Fold 2 - Epoch 42/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.91it/s]
# Fold 2 - Epoch 42/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.27it/s]
# 2025-02-15 19:19:43,365 - INFO - Fold 2, Epoch 42/100 | Train Loss: 0.0209, Train Balanced Accuracy: 0.9943 | Val Loss: 0.6440, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 43/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.92it/s]
# Fold 2 - Epoch 43/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.94it/s]
# 2025-02-15 19:19:47,457 - INFO - Fold 2, Epoch 43/100 | Train Loss: 0.0214, Train Balanced Accuracy: 0.9949 | Val Loss: 0.6444, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 44/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.79it/s]
# Fold 2 - Epoch 44/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.93it/s]
# 2025-02-15 19:19:51,645 - INFO - Fold 2, Epoch 44/100 | Train Loss: 0.0260, Train Balanced Accuracy: 0.9924 | Val Loss: 0.6440, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 45/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.73it/s]
# Fold 2 - Epoch 45/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.88it/s]
# 2025-02-15 19:19:55,814 - INFO - Fold 2, Epoch 45/100 | Train Loss: 0.0205, Train Balanced Accuracy: 0.9930 | Val Loss: 0.6422, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 46/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.92it/s]
# Fold 2 - Epoch 46/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.22it/s]
# 2025-02-15 19:19:59,885 - INFO - Fold 2, Epoch 46/100 | Train Loss: 0.0307, Train Balanced Accuracy: 0.9901 | Val Loss: 0.6427, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 47/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 2 - Epoch 47/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.26it/s]
# 2025-02-15 19:20:04,001 - INFO - Fold 2, Epoch 47/100 | Train Loss: 0.0282, Train Balanced Accuracy: 0.9915 | Val Loss: 0.6434, Val Balanced Accuracy: 0.7323
# Fold 2 - Epoch 48/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.87it/s]
# Fold 2 - Epoch 48/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.39it/s]
# 2025-02-15 19:20:08,095 - INFO - Fold 2, Epoch 48/100 | Train Loss: 0.0236, Train Balanced Accuracy: 0.9915 | Val Loss: 0.6434, Val Balanced Accuracy: 0.7310
# Fold 2 - Epoch 49/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.89it/s]
# ...
# Fold 5 - Epoch 52/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.73it/s]
# Fold 5 - Epoch 52/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.62it/s]
# 2025-02-15 19:40:57,604 - INFO - Fold 5, Epoch 52/100 | Train Loss: 0.0189, Train Balanced Accuracy: 0.9938 | Val Loss: 0.7037, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 53/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.94it/s]
# Fold 5 - Epoch 53/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.39it/s]
# 2025-02-15 19:41:01,650 - INFO - Fold 5, Epoch 53/100 | Train Loss: 0.0208, Train Balanced Accuracy: 0.9957 | Val Loss: 0.7029, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 54/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 5 - Epoch 54/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.10it/s]
# 2025-02-15 19:41:05,788 - INFO - Fold 5, Epoch 54/100 | Train Loss: 0.0147, Train Balanced Accuracy: 0.9967 | Val Loss: 0.7027, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 55/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 5 - Epoch 55/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.72it/s]
# 2025-02-15 19:41:09,885 - INFO - Fold 5, Epoch 55/100 | Train Loss: 0.0213, Train Balanced Accuracy: 0.9929 | Val Loss: 0.7014, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 56/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 5 - Epoch 56/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.49it/s]
# 2025-02-15 19:41:13,980 - INFO - Fold 5, Epoch 56/100 | Train Loss: 0.0245, Train Balanced Accuracy: 0.9915 | Val Loss: 0.7007, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 57/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 5 - Epoch 57/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.87it/s]
# 2025-02-15 19:41:18,056 - INFO - Fold 5, Epoch 57/100 | Train Loss: 0.0247, Train Balanced Accuracy: 0.9920 | Val Loss: 0.7011, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 58/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.94it/s]
# Fold 5 - Epoch 58/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.94it/s]
# 2025-02-15 19:41:22,135 - INFO - Fold 5, Epoch 58/100 | Train Loss: 0.0208, Train Balanced Accuracy: 0.9934 | Val Loss: 0.7008, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 59/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 5 - Epoch 59/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.46it/s]
# 2025-02-15 19:41:26,236 - INFO - Fold 5, Epoch 59/100 | Train Loss: 0.0218, Train Balanced Accuracy: 0.9920 | Val Loss: 0.7012, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 60/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.77it/s]
# Fold 5 - Epoch 60/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.82it/s]
# 2025-02-15 19:41:30,378 - INFO - Fold 5, Epoch 60/100 | Train Loss: 0.0190, Train Balanced Accuracy: 0.9952 | Val Loss: 0.7018, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 61/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.95it/s]
# Fold 5 - Epoch 61/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.44it/s]
# 2025-02-15 19:41:34,411 - INFO - Fold 5, Epoch 61/100 | Train Loss: 0.0175, Train Balanced Accuracy: 0.9949 | Val Loss: 0.7021, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 62/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.75it/s]
# Fold 5 - Epoch 62/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.57it/s]
# 2025-02-15 19:41:38,584 - INFO - Fold 5, Epoch 62/100 | Train Loss: 0.0263, Train Balanced Accuracy: 0.9915 | Val Loss: 0.7019, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 63/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.87it/s]
# Fold 5 - Epoch 63/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.18it/s]
# 2025-02-15 19:41:42,697 - INFO - Fold 5, Epoch 63/100 | Train Loss: 0.0280, Train Balanced Accuracy: 0.9910 | Val Loss: 0.7026, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 64/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.87it/s]
# Fold 5 - Epoch 64/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.32it/s]
# 2025-02-15 19:41:46,797 - INFO - Fold 5, Epoch 64/100 | Train Loss: 0.0201, Train Balanced Accuracy: 0.9953 | Val Loss: 0.7032, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 65/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.94it/s]
# Fold 5 - Epoch 65/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.49it/s]
# 2025-02-15 19:41:50,839 - INFO - Fold 5, Epoch 65/100 | Train Loss: 0.0188, Train Balanced Accuracy: 0.9962 | Val Loss: 0.7024, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 66/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.96it/s]
# Fold 5 - Epoch 66/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.47it/s]
# 2025-02-15 19:41:54,868 - INFO - Fold 5, Epoch 66/100 | Train Loss: 0.0177, Train Balanced Accuracy: 0.9967 | Val Loss: 0.7032, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 67/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 5 - Epoch 67/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.74it/s]
# 2025-02-15 19:41:58,965 - INFO - Fold 5, Epoch 67/100 | Train Loss: 0.0217, Train Balanced Accuracy: 0.9934 | Val Loss: 0.7043, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 68/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.85it/s]
# Fold 5 - Epoch 68/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.90it/s]
# 2025-02-15 19:42:03,040 - INFO - Fold 5, Epoch 68/100 | Train Loss: 0.0221, Train Balanced Accuracy: 0.9924 | Val Loss: 0.7049, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 69/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.84it/s]
# Fold 5 - Epoch 69/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.05it/s]
# 2025-02-15 19:42:07,181 - INFO - Fold 5, Epoch 69/100 | Train Loss: 0.0252, Train Balanced Accuracy: 0.9910 | Val Loss: 0.7058, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 70/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.80it/s]
# Fold 5 - Epoch 70/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.00it/s]
# 2025-02-15 19:42:11,357 - INFO - Fold 5, Epoch 70/100 | Train Loss: 0.0235, Train Balanced Accuracy: 0.9924 | Val Loss: 0.7051, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 71/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.74it/s]
# Fold 5 - Epoch 71/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.56it/s]
# 2025-02-15 19:42:15,537 - INFO - Fold 5, Epoch 71/100 | Train Loss: 0.0216, Train Balanced Accuracy: 0.9934 | Val Loss: 0.7049, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 72/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.76it/s]
# Fold 5 - Epoch 72/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.52it/s]
# 2025-02-15 19:42:19,705 - INFO - Fold 5, Epoch 72/100 | Train Loss: 0.0225, Train Balanced Accuracy: 0.9943 | Val Loss: 0.7053, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 73/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.93it/s]
# Fold 5 - Epoch 73/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.06it/s]
# 2025-02-15 19:42:23,783 - INFO - Fold 5, Epoch 73/100 | Train Loss: 0.0200, Train Balanced Accuracy: 0.9939 | Val Loss: 0.7049, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 74/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.78it/s]
# Fold 5 - Epoch 74/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.50it/s]
# 2025-02-15 19:42:27,940 - INFO - Fold 5, Epoch 74/100 | Train Loss: 0.0272, Train Balanced Accuracy: 0.9929 | Val Loss: 0.7043, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 75/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.86it/s]
# Fold 5 - Epoch 75/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.62it/s]
# 2025-02-15 19:42:32,102 - INFO - Fold 5, Epoch 75/100 | Train Loss: 0.0222, Train Balanced Accuracy: 0.9948 | Val Loss: 0.7041, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 76/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.82it/s]
# Fold 5 - Epoch 76/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.88it/s]
# 2025-02-15 19:42:36,276 - INFO - Fold 5, Epoch 76/100 | Train Loss: 0.0198, Train Balanced Accuracy: 0.9939 | Val Loss: 0.7030, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 77/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.73it/s]
# Fold 5 - Epoch 77/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.06it/s]
# 2025-02-15 19:42:40,498 - INFO - Fold 5, Epoch 77/100 | Train Loss: 0.0239, Train Balanced Accuracy: 0.9948 | Val Loss: 0.7033, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 78/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 5 - Epoch 78/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.61it/s]
# 2025-02-15 19:42:44,571 - INFO - Fold 5, Epoch 78/100 | Train Loss: 0.0217, Train Balanced Accuracy: 0.9938 | Val Loss: 0.7025, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 79/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.72it/s]
# Fold 5 - Epoch 79/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.81it/s]
# 2025-02-15 19:42:48,747 - INFO - Fold 5, Epoch 79/100 | Train Loss: 0.0196, Train Balanced Accuracy: 0.9952 | Val Loss: 0.7022, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 80/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.91it/s]
# Fold 5 - Epoch 80/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.68it/s]
# 2025-02-15 19:42:52,871 - INFO - Fold 5, Epoch 80/100 | Train Loss: 0.0216, Train Balanced Accuracy: 0.9934 | Val Loss: 0.7027, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 81/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.71it/s]
# Fold 5 - Epoch 81/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.34it/s]
# 2025-02-15 19:42:57,092 - INFO - Fold 5, Epoch 81/100 | Train Loss: 0.0226, Train Balanced Accuracy: 0.9915 | Val Loss: 0.7020, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 82/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.70it/s]
# Fold 5 - Epoch 82/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.99it/s]
# 2025-02-15 19:43:01,344 - INFO - Fold 5, Epoch 82/100 | Train Loss: 0.0220, Train Balanced Accuracy: 0.9943 | Val Loss: 0.7006, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 83/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.69it/s]
# Fold 5 - Epoch 83/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.65it/s]
# 2025-02-15 19:43:05,555 - INFO - Fold 5, Epoch 83/100 | Train Loss: 0.0203, Train Balanced Accuracy: 0.9947 | Val Loss: 0.7014, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 84/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.80it/s]
# Fold 5 - Epoch 84/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.64it/s]
# 2025-02-15 19:43:09,761 - INFO - Fold 5, Epoch 84/100 | Train Loss: 0.0263, Train Balanced Accuracy: 0.9929 | Val Loss: 0.7023, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 85/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.72it/s]
# Fold 5 - Epoch 85/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.92it/s]
# 2025-02-15 19:43:14,001 - INFO - Fold 5, Epoch 85/100 | Train Loss: 0.0231, Train Balanced Accuracy: 0.9938 | Val Loss: 0.7018, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 86/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.83it/s]
# Fold 5 - Epoch 86/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.68it/s]
# 2025-02-15 19:43:18,102 - INFO - Fold 5, Epoch 86/100 | Train Loss: 0.0237, Train Balanced Accuracy: 0.9938 | Val Loss: 0.7028, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 87/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 5 - Epoch 87/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.62it/s]
# 2025-02-15 19:43:22,178 - INFO - Fold 5, Epoch 87/100 | Train Loss: 0.0241, Train Balanced Accuracy: 0.9924 | Val Loss: 0.7019, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 88/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.89it/s]
# Fold 5 - Epoch 88/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.55it/s]
# 2025-02-15 19:43:26,247 - INFO - Fold 5, Epoch 88/100 | Train Loss: 0.0154, Train Balanced Accuracy: 0.9962 | Val Loss: 0.7018, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 89/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 5 - Epoch 89/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.88it/s]
# 2025-02-15 19:43:30,376 - INFO - Fold 5, Epoch 89/100 | Train Loss: 0.0168, Train Balanced Accuracy: 0.9972 | Val Loss: 0.7025, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 90/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.78it/s]
# Fold 5 - Epoch 90/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.59it/s]
# 2025-02-15 19:43:34,524 - INFO - Fold 5, Epoch 90/100 | Train Loss: 0.0232, Train Balanced Accuracy: 0.9943 | Val Loss: 0.7027, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 91/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.92it/s]
# Fold 5 - Epoch 91/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.13it/s]
# 2025-02-15 19:43:38,602 - INFO - Fold 5, Epoch 91/100 | Train Loss: 0.0207, Train Balanced Accuracy: 0.9938 | Val Loss: 0.7030, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 92/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s]
# Fold 5 - Epoch 92/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.93it/s]
# 2025-02-15 19:43:42,707 - INFO - Fold 5, Epoch 92/100 | Train Loss: 0.0335, Train Balanced Accuracy: 0.9905 | Val Loss: 0.7029, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 93/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.82it/s]
# Fold 5 - Epoch 93/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.14it/s]
# 2025-02-15 19:43:46,854 - INFO - Fold 5, Epoch 93/100 | Train Loss: 0.0211, Train Balanced Accuracy: 0.9953 | Val Loss: 0.7037, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 94/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.83it/s]
# Fold 5 - Epoch 94/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.39it/s]
# 2025-02-15 19:43:50,981 - INFO - Fold 5, Epoch 94/100 | Train Loss: 0.0231, Train Balanced Accuracy: 0.9925 | Val Loss: 0.7045, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 95/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.94it/s]
# Fold 5 - Epoch 95/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.32it/s]
# 2025-02-15 19:43:55,035 - INFO - Fold 5, Epoch 95/100 | Train Loss: 0.0227, Train Balanced Accuracy: 0.9925 | Val Loss: 0.7050, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 96/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.87it/s]
# Fold 5 - Epoch 96/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.21it/s]
# 2025-02-15 19:43:59,142 - INFO - Fold 5, Epoch 96/100 | Train Loss: 0.0223, Train Balanced Accuracy: 0.9941 | Val Loss: 0.7041, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 97/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.87it/s]
# Fold 5 - Epoch 97/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.86it/s]
# 2025-02-15 19:44:03,206 - INFO - Fold 5, Epoch 97/100 | Train Loss: 0.0237, Train Balanced Accuracy: 0.9924 | Val Loss: 0.7040, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 98/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.74it/s]
# Fold 5 - Epoch 98/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.21it/s]
# 2025-02-15 19:44:07,411 - INFO - Fold 5, Epoch 98/100 | Train Loss: 0.0207, Train Balanced Accuracy: 0.9953 | Val Loss: 0.7042, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 99/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.95it/s]
# Fold 5 - Epoch 99/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  7.67it/s]
# 2025-02-15 19:44:11,506 - INFO - Fold 5, Epoch 99/100 | Train Loss: 0.0249, Train Balanced Accuracy: 0.9920 | Val Loss: 0.7052, Val Balanced Accuracy: 0.7134
# Fold 5 - Epoch 100/100 - Training: 100%|██████████| 17/17 [00:03<00:00,  4.88it/s]
# Fold 5 - Epoch 100/100 - Validation: 100%|██████████| 5/5 [00:00<00:00,  8.57it/s]
# 2025-02-15 19:44:15,581 - INFO - Fold 5, Epoch 100/100 | Train Loss: 0.0239, Train Balanced Accuracy: 0.9919 | Val Loss: 0.7041, Val Balanced Accuracy: 0.7134
# 2025-02-15 19:44:15,581 - INFO - Fold 5 - Best Validation Balanced Accuracy: 0.7495
# 2025-02-15 19:44:15,581 - INFO - Average Validation Balanced Accuracy across all folds: 0.7597

# %% [markdown]
# ## Inference (Individually on each checkpoint)

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
import os
from PIL import Image
import logging

# Setup logging
log_file = "efficientnet_test_inference.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations for test dataset
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load test data
def load_test_data(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class TestDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define the model class
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Load test dataset
classes = ['Atypical', 'Normal']
test_images, test_labels = load_test_data('/data/Mitosis_Detection/MICCAI25/AMI-Br_dataset/Test_Held_out/Images', classes)
test_dataset = TestDataset(test_images, test_labels, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Evaluate each fold model
num_folds = 5
fold_accuracies = []

for fold in range(num_folds):
    model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'
    if not os.path.exists(model_path):
        logger.warning(f"Model checkpoint not found: {model_path}")
        continue

    logger.info(f"Evaluating Fold {fold + 1} Model")
    model = BinaryEfficientNet().to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    test_preds = []
    test_targets = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            labels = labels.float().unsqueeze(1)
            outputs = model(images)
            test_preds.extend((outputs > 0.5).cpu().numpy())
            test_targets.extend(labels.cpu().numpy())

    balanced_acc = balanced_accuracy_score(test_targets, test_preds)
    fold_accuracies.append(balanced_acc)
    logger.info(f"Fold {fold + 1} - Test Balanced Accuracy: {balanced_acc:.4f}")

# Calculate and log overall performance
if fold_accuracies:
    average_accuracy = sum(fold_accuracies) / len(fold_accuracies)
    logger.info(f"Average Test Balanced Accuracy across all folds: {average_accuracy:.4f}")
# Out:
# 2025-02-15 19:49:52,803 - INFO - Evaluating Fold 1 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-15 19:49:53,791 - INFO - Fold 1 - Test Balanced Accuracy: 0.7474
# 2025-02-15 19:49:53,791 - INFO - Evaluating Fold 2 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-15 19:49:54,648 - INFO - Fold 2 - Test Balanced Accuracy: 0.7533
# 2025-02-15 19:49:54,648 - INFO - Evaluating Fold 3 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-15 19:49:55,542 - INFO - Fold 3 - Test Balanced Accuracy: 0.7586
# 2025-02-15 19:49:55,543 - INFO - Evaluating Fold 4 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-15 19:49:56,395 - INFO - Fold 4 - Test Balanced Accuracy: 0.7260
# 2025-02-15 19:49:56,396 - INFO - Evaluating Fold 5 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-15 19:49:57,150 - INFO - Fold 5 - Test Balanced Accuracy: 0.7895
# 2025-02-15 19:49:57,151 - INFO - Average Test Balanced Accuracy across all folds: 0.7549

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
import os
from PIL import Image
import logging
import numpy as np

# Setup logging
log_file = "efficientnet_test_inference.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations for test dataset
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load test data
def load_test_data(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class TestDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define the model class
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Load test dataset
classes = ['Atypical', 'Normal']
test_images, test_labels = load_test_data('/data/Mitosis_Detection/MICCAI25/AMI-Br_dataset/Test_Held_out/Images', classes)
test_dataset = TestDataset(test_images, test_labels, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Evaluate each fold model
num_folds = 5
fold_accuracies = []

for fold in range(num_folds):
    model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'
    if not os.path.exists(model_path):
        logger.warning(f"Model checkpoint not found: {model_path}")
        continue

    logger.info(f"Evaluating Fold {fold + 1} Model")
    model = BinaryEfficientNet().to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    test_preds = []
    test_targets = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            labels = labels.float().unsqueeze(1)
            outputs = model(images)
            test_preds.extend((outputs > 0.5).cpu().numpy())
            test_targets.extend(labels.cpu().numpy())

    balanced_acc = balanced_accuracy_score(test_targets, test_preds)
    fold_accuracies.append(balanced_acc)
    logger.info(f"Fold {fold + 1} - Test Balanced Accuracy: {balanced_acc:.4f}")

# Calculate and log overall performance
if fold_accuracies:
    average_accuracy = np.mean(fold_accuracies)
    std_accuracy = np.std(fold_accuracies)
    logger.info(f"Average Test Balanced Accuracy across all folds: {average_accuracy:.4f}")
    logger.info(f"Standard Deviation of Balanced Accuracy: {std_accuracy:.4f}")
# Out:
# 2025-02-26 14:50:53,678 - INFO - Evaluating Fold 1 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:51:03,413 - INFO - Fold 1 - Test Balanced Accuracy: 0.7474
# 2025-02-26 14:51:03,414 - INFO - Evaluating Fold 2 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:51:13,580 - INFO - Fold 2 - Test Balanced Accuracy: 0.7533
# 2025-02-26 14:51:13,581 - INFO - Evaluating Fold 3 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:51:22,790 - INFO - Fold 3 - Test Balanced Accuracy: 0.7586
# 2025-02-26 14:51:22,791 - INFO - Evaluating Fold 4 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:51:33,242 - INFO - Fold 4 - Test Balanced Accuracy: 0.7260
# 2025-02-26 14:51:33,245 - INFO - Evaluating Fold 5 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:51:43,019 - INFO - Fold 5 - Test Balanced Accuracy: 0.7895
# 2025-02-26 14:51:43,020 - INFO - Average Test Balanced Accuracy across all folds: 0.7549
# 2025-02-26 14:51:43,021 - INFO - Standard Deviation of Balanced Accuracy: 0.0205

# %% [markdown]
# ## Majority Vote Ensembling

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
import os
from PIL import Image
import logging
import numpy as np

# Setup logging
log_file = "efficientnet_test_inference.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations for test dataset
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load test data
def load_test_data(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class TestDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define the model class
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Load test dataset
classes = ['Atypical', 'Normal']
test_images, test_labels = load_test_data('/data/Mitosis_Detection/MICCAI25/AMI-Br_dataset/Test_Held_out/Images', classes)
test_dataset = TestDataset(test_images, test_labels, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Evaluate ensembled model using Majority Voting
num_folds = 5
models = []

for fold in range(num_folds):
    model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'
    if not os.path.exists(model_path):
        logger.warning(f"Model checkpoint not found: {model_path}")
        continue
    
    model = BinaryEfficientNet().to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    models.append(model)

if not models:
    logger.error("No valid models loaded for ensembling.")
    exit()

logger.info("Performing majority voting ensembling inference")

test_preds = []
test_targets = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        labels = labels.float().unsqueeze(1)

        all_model_preds = []
        for model in models:
            outputs = model(images)
            preds = (outputs > 0.5).cpu().numpy()
            all_model_preds.append(preds)
        
        # Majority Voting
        all_model_preds = np.array(all_model_preds)  # Shape: (num_models, batch_size, 1)
        majority_preds = np.round(np.mean(all_model_preds, axis=0))  # Compute majority vote

        test_preds.extend(majority_preds)
        test_targets.extend(labels.cpu().numpy())

balanced_acc = balanced_accuracy_score(test_targets, test_preds)
logger.info(f"Majority Voting Ensembled Test Balanced Accuracy: {balanced_acc:.4f}")
# Out:
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# 2025-02-15 19:52:47,830 - INFO - Performing majority voting ensembling inference
# Loaded pretrained weights for efficientnet-b0
# 2025-02-15 19:52:49,962 - INFO - Majority Voting Ensembled Test Balanced Accuracy: 0.7888

# %% [markdown]
# ## AtNorM-MD

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
import os
from PIL import Image
import logging
import numpy as np

# Setup logging
log_file = "efficientnet_test_inference.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations for test dataset
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load test data
def load_test_data(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class TestDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define the model class
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Load test dataset
classes = ['Atypical', 'Normal']
test_images, test_labels = load_test_data('/data/MICCAI25_Github/datasets/AtNorM-MD', classes)
test_dataset = TestDataset(test_images, test_labels, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Evaluate ensembled model using Majority Voting
num_folds = 5
models = []

for fold in range(num_folds):
    model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'
    if not os.path.exists(model_path):
        logger.warning(f"Model checkpoint not found: {model_path}")
        continue
    
    model = BinaryEfficientNet().to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    models.append(model)

if not models:
    logger.error("No valid models loaded for ensembling.")
    exit()

logger.info("Performing majority voting ensembling inference")

test_preds = []
test_targets = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        labels = labels.float().unsqueeze(1)

        all_model_preds = []
        for model in models:
            outputs = model(images)
            preds = (outputs > 0.5).cpu().numpy()
            all_model_preds.append(preds)
        
        # Majority Voting
        all_model_preds = np.array(all_model_preds)  # Shape: (num_models, batch_size, 1)
        majority_preds = np.round(np.mean(all_model_preds, axis=0))  # Compute majority vote

        test_preds.extend(majority_preds)
        test_targets.extend(labels.cpu().numpy())

balanced_acc = balanced_accuracy_score(test_targets, test_preds)
logger.info(f"Majority Voting Ensembled Test Balanced Accuracy: {balanced_acc:.4f}")
# Out:
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# 2025-02-20 12:11:15,040 - INFO - Performing majority voting ensembling inference
# 2025-02-20 12:11:20,778 - INFO - Majority Voting Ensembled Test Balanced Accuracy: 0.7147

# %% [markdown]
# ## AtNorM-Br

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
import os
from PIL import Image
import logging
import numpy as np

# Setup logging
log_file = "efficientnet_test_inference.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations for test dataset
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load test data
def load_test_data(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class TestDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define the model class
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Load test dataset
classes = ['Atypical', 'Normal']
test_images, test_labels = load_test_data('/data/MICCAI25_Github/datasets/AtNorM-Br', classes)
test_dataset = TestDataset(test_images, test_labels, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Evaluate ensembled model using Majority Voting
num_folds = 5
models = []

for fold in range(num_folds):
    model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'
    if not os.path.exists(model_path):
        logger.warning(f"Model checkpoint not found: {model_path}")
        continue
    
    model = BinaryEfficientNet().to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    models.append(model)

if not models:
    logger.error("No valid models loaded for ensembling.")
    exit()

logger.info("Performing majority voting ensembling inference")

test_preds = []
test_targets = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        labels = labels.float().unsqueeze(1)

        all_model_preds = []
        for model in models:
            outputs = model(images)
            preds = (outputs > 0.5).cpu().numpy()
            all_model_preds.append(preds)
        
        # Majority Voting
        all_model_preds = np.array(all_model_preds)  # Shape: (num_models, batch_size, 1)
        majority_preds = np.round(np.mean(all_model_preds, axis=0))  # Compute majority vote

        test_preds.extend(majority_preds)
        test_targets.extend(labels.cpu().numpy())

balanced_acc = balanced_accuracy_score(test_targets, test_preds)
logger.info(f"Majority Voting Ensembled Test Balanced Accuracy: {balanced_acc:.4f}")
# Out:
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 17:06:11,836 - INFO - Performing majority voting ensembling inference
# 2025-02-26 17:06:21,036 - INFO - Majority Voting Ensembled Test Balanced Accuracy: 0.6940

# %% [markdown]
# ## AtNorM-MD

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
import os
from PIL import Image
import logging
import numpy as np

# Setup logging
log_file = "efficientnet_test_inference.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations for test dataset
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load test data
def load_test_data(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class TestDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define the model class
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Load test dataset
classes = ['Atypical', 'Normal']
test_images, test_labels = load_test_data('/data/MICCAI25_Github/datasets/AtNorM-MD', classes)
test_dataset = TestDataset(test_images, test_labels, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Evaluate each fold model
num_folds = 5
fold_accuracies = []

for fold in range(num_folds):
    model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'
    if not os.path.exists(model_path):
        logger.warning(f"Model checkpoint not found: {model_path}")
        continue

    logger.info(f"Evaluating Fold {fold + 1} Model")
    model = BinaryEfficientNet().to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    test_preds = []
    test_targets = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            labels = labels.float().unsqueeze(1)
            outputs = model(images)
            test_preds.extend((outputs > 0.5).cpu().numpy())
            test_targets.extend(labels.cpu().numpy())

    balanced_acc = balanced_accuracy_score(test_targets, test_preds)
    fold_accuracies.append(balanced_acc)
    logger.info(f"Fold {fold + 1} - Test Balanced Accuracy: {balanced_acc:.4f}")

# Calculate and log overall performance
if fold_accuracies:
    average_accuracy = np.mean(fold_accuracies)
    std_accuracy = np.std(fold_accuracies)
    logger.info(f"Average Test Balanced Accuracy across all folds: {average_accuracy:.4f}")
    logger.info(f"Standard Deviation of Balanced Accuracy: {std_accuracy:.4f}")
# Out:
# 2025-02-26 14:55:47,676 - INFO - Evaluating Fold 1 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:56:00,756 - INFO - Fold 1 - Test Balanced Accuracy: 0.7132
# 2025-02-26 14:56:00,757 - INFO - Evaluating Fold 2 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:56:12,372 - INFO - Fold 2 - Test Balanced Accuracy: 0.6623
# 2025-02-26 14:56:12,373 - INFO - Evaluating Fold 3 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:56:25,406 - INFO - Fold 3 - Test Balanced Accuracy: 0.6718
# 2025-02-26 14:56:25,406 - INFO - Evaluating Fold 4 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:56:38,362 - INFO - Fold 4 - Test Balanced Accuracy: 0.6591
# 2025-02-26 14:56:38,363 - INFO - Evaluating Fold 5 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-26 14:56:50,779 - INFO - Fold 5 - Test Balanced Accuracy: 0.7024
# 2025-02-26 14:56:50,780 - INFO - Average Test Balanced Accuracy across all folds: 0.6818
# 2025-02-26 14:56:50,781 - INFO - Standard Deviation of Balanced Accuracy: 0.0219

# %% [markdown]
# ## AtNorM-Br

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import balanced_accuracy_score
from efficientnet_pytorch import EfficientNet
import os
from PIL import Image
import logging
import numpy as np

# Setup logging
log_file = "efficientnet_test_inference.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Define transformations for test dataset
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to load test data
def load_test_data(folder_path, classes):
    images = []
    labels = []
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(classes)}

    for cls_name in classes:
        class_folder = os.path.join(folder_path, cls_name)
        if not os.path.isdir(class_folder):
            continue
        for file_name in os.listdir(class_folder):
            file_path = os.path.join(class_folder, file_name)
            if os.path.isfile(file_path):
                images.append(file_path)
                labels.append(class_to_idx[cls_name])

    return images, labels

# Custom Dataset class
class TestDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define the model class
class BinaryEfficientNet(nn.Module):
    def __init__(self):
        super(BinaryEfficientNet, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0')
        self.model._fc = nn.Sequential(
            nn.Linear(self.model._fc.in_features, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Load test dataset
classes = ['Atypical', 'Normal']
test_images, test_labels = load_test_data('/data/MICCAI25_Github/datasets/AtNorM-Br', classes)
test_dataset = TestDataset(test_images, test_labels, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Evaluate each fold model
num_folds = 5
fold_accuracies = []

for fold in range(num_folds):
    model_path = f'Ami-br_efficientnet_master_baseline_fold{fold + 1}_best.pth'
    if not os.path.exists(model_path):
        logger.warning(f"Model checkpoint not found: {model_path}")
        continue

    logger.info(f"Evaluating Fold {fold + 1} Model")
    model = BinaryEfficientNet().to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()

    test_preds = []
    test_targets = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            labels = labels.float().unsqueeze(1)
            outputs = model(images)
            test_preds.extend((outputs > 0.5).cpu().numpy())
            test_targets.extend(labels.cpu().numpy())

    balanced_acc = balanced_accuracy_score(test_targets, test_preds)
    fold_accuracies.append(balanced_acc)
    logger.info(f"Fold {fold + 1} - Test Balanced Accuracy: {balanced_acc:.4f}")

# Calculate and log overall performance
if fold_accuracies:
    average_accuracy = np.mean(fold_accuracies)
    std_accuracy = np.std(fold_accuracies)
    logger.info(f"Average Test Balanced Accuracy across all folds: {average_accuracy:.4f}")
    logger.info(f"Standard Deviation of Balanced Accuracy: {std_accuracy:.4f}")
# Out:
# 2025-02-27 14:53:54,926 - INFO - Evaluating Fold 1 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-27 14:53:55,938 - INFO - Fold 1 - Test Balanced Accuracy: 0.6777
# 2025-02-27 14:53:55,939 - INFO - Evaluating Fold 2 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-27 14:53:56,619 - INFO - Fold 2 - Test Balanced Accuracy: 0.6822
# 2025-02-27 14:53:56,619 - INFO - Evaluating Fold 3 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-27 14:53:57,273 - INFO - Fold 3 - Test Balanced Accuracy: 0.6640
# 2025-02-27 14:53:57,274 - INFO - Evaluating Fold 4 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-27 14:53:57,950 - INFO - Fold 4 - Test Balanced Accuracy: 0.6910
# 2025-02-27 14:53:57,951 - INFO - Evaluating Fold 5 Model
# Loaded pretrained weights for efficientnet-b0
# 2025-02-27 14:53:58,637 - INFO - Fold 5 - Test Balanced Accuracy: 0.7080
# 2025-02-27 14:53:58,638 - INFO - Average Test Balanced Accuracy across all folds: 0.6846
# 2025-02-27 14:53:58,639 - INFO - Standard Deviation of Balanced Accuracy: 0.0146
